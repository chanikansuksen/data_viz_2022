# %% [markdown]
# <a href="https://colab.research.google.com/github/chanikansuksen/data_viz_2022/blob/main/Project_Datastudio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # ใช้จัดการข้อมูลต่าง ๆ ที่เป็นตาราง พวกexcel ,CSV
from google.colab import drive # เชื่อม google drive กับ colab ของเรา นี้เป็นคำสั่งเชื่อม |accout colab กับ Drive ควรเป็น accout เดียวกัน|
drive.mount('/content/drive')
import os # การจัดเก็บเกี่ยวกับไฟล์ต่าง ๆ มันอยู่ที่โฟลเดอร์ไหน จะ list โฟล์เดอร์ออกมา
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/DataViz22_data' #บอกทางผ่านในการไปเอาไฟล์ของเรา ว่าผ่านทางไหนบ้าง

# %% [markdown]
# # ดึงข้อมูล ไฟล์1

# %%
covid_file_path_1= os.path.join(path,'data1_1.csv')
print(covid_file_path_1)
# Out:
# /content/drive/My Drive/DataViz22_data/data1_1.csv

# %%
date_covid_1 = pd.read_csv(covid_file_path_1)
date_covid_1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %%
covid_file_path_2 = os.path.join(path,'data1_2.csv')
print(covid_file_path_2)
# Out:
# /content/drive/My Drive/DataViz22_data/data1_2.csv

# %%
date_covid_2 = pd.read_csv(covid_file_path_2)
date_covid_2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %%
covid_file_path_3= os.path.join(path,'data1_3.csv')
print(covid_file_path_3)
# Out:
# /content/drive/My Drive/DataViz22_data/data1_3.csv

# %%
date_covid_3 = pd.read_csv(covid_file_path_3)
date_covid_3
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %%
covid_file_path_4= os.path.join(path,'data1_4.csv')
print(covid_file_path_4)
# Out:
# /content/drive/My Drive/DataViz22_data/data1_4.csv

# %%
date_covid_4 = pd.read_csv(covid_file_path_4)
date_covid_4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# # รวมไฟล์1 แกน Y

# %%
import pandas as pd

# %%
data1 = pd.concat([date_covid_1, date_covid_2, date_covid_3, date_covid_4] ) # เอาตารางมาต่อกัน
data1
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# # ตัดคอลัมน์ไฟล์รวม1

# %%
show_data1 = data1[['No.','announce_date','sex','age','Unit','nationality','risk','province_of_onset']]
show_data1
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# ...

# %%
set(show_data1['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  nan,
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
# ...

# %% [markdown]
# # แทนที่ชื่อจังหวัด

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !ls
# Out:
# data_project.csv  sample_data		    thsarabunnew-webfont.ttf.1
# drive		  thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# re_name=show_data1.replace({'\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',  'USA':'ไม่ระบุ', 'nan':'ไม่ระบุ', '\xa0กาญจนบุรี':'กาญจนบุรี', 
#                                     '\xa0ชลบุรี':'ชลบุรี', '\xa0ตราด':'ตราด',  '\xa0นครปฐม': 'นครปฐม', '\xa0สมุทรสงคราม':'สมุทรสงคราม',
#                                     '\xa0สมุทรสาคร':'สมุทรสาคร',  '\xa0อุทัยธานี': 'อุทัยธานี', 'กทม':'กรุงเทพมหานคร',  'กทม.':'กรุงเทพมหานคร',
#                                      'กบินทร์บุรี':'ไม่ระบุ',  'กระบี่': 'กระบี่', 'กระบี่ี่':'กระบี่',  'กรุงเทพ':'กรุงเทพมหานคร',
#                                      'กรุงเทพมหานคร': 'กรุงเทพมหานคร', 'กรุงเทพมหานคร.': 'กรุงเทพมหานคร',  'กรุงเทพมหานคร. / พระนครศรีอยุธยา':'ไม่ระบุ', 'กรุงเทพมหานคร. / ศรีสะเกษ':'ไม่ระบุ',
#                                      'กรุงเทพฯ': 'กรุงเทพมหานคร',  'กะทู้':'ไม่ระบุ', 'กัมพูชา':'ไม่ระบุ',  'กาญจนบุรี':'กาญจนบุรี',
#                                      'กาญจบุรี':'กาญจนบุรี',  'กาญนบุรี':'กาญจนบุรี', 'กาฬสิน': 'กาฬสินธุ์',  'กาฬสินธิ์': 'กาฬสินธุ์',
#                                      'กาฬสินธุ์': 'กาฬสินธุ์', 'กาฬสินธุ์\xa0': 'กาฬสินธุ์',  'กาฬสินธ์': 'กาฬสินธุ์', 'กำเพงเพชร':'กำแพงเพชร',
#                                      'กำแพง':'กำแพงเพชร', 'กำแพงเพชร':'กำแพงเพชร',  'กำแพงเพชร\xa0': 'กำแพงเพชร',  'กําแพงเพชร': 'กำแพงเพชร',
#                                      'ขอนแก่น':'ขอนแก่น',  'ขอนแก่น\xa0': 'ขอนแก่น',  'ขอนแก่่น': 'ขอนแก่น',  'ขัยนาท':'ชัยนาท',
#                                      'ขัยภูมิ':'ชัยภูมิ', 'ขานุวรลักษณ์บุรี':'ไม่ระบุ', 'คนไทยเดินทางกลับจากต่างประเทศ':'ไม่ระบุ',  'คลองเตย':'ไม่ระบุ',
#                                      'จ.กรุงเทพมหานคร': 'กรุงเทพมหานคร', 'จ.ภูเก็ต':'ภูเก็ต',  'จ.ราชบุรี': 'ราชบุรี',  'จ.สุราษฎร์ธานี': 'สุราษฎร์ธานี',
#                                      'จังหวัดสมุทรสาคร': 'สมุทรสาคร',  'จันทบุรี': 'จันทบุรี', 'ฉะเชองเทราร': 'ฉะเชิงเทรา',  'ฉะเชิงเทรา': 'ฉะเชิงเทรา',
#                                      'ชมพร':'ชุมพร',  'ชลบุรี': 'ชลบุรี',  'ชลบุรี\t': 'ชลบุรี', 'ชลบุรี\xa0': 'ชลบุรี',
#                                      'ชลบุุรี':'ชลบุรี', 'ชอนแก่น':'ขอนแก่น',  'ชัยนาถ': 'ชัยนาท',  'ชัยนาท': 'ชัยนาท',
#                                      'ชัยบาดาล':'ไม่ระบุ', 'ชัยภูมิ': 'ชัยภูมิ',  'ชัยภูมิ\xa0': 'ชัยภูมิ', 'ชุมพร':'ชุมพร',
#                                      'ชุุมพร':'ชุมพร',  'ชุุุมพร':'ชุมพร', 'ดอนมดแดง':'ไม่ระบุ',  'ดินแดง':'ไม่ระบุ',
#                                      'ตรัง':'ตรัง',  'ตรััง':'ตรัง', 'ตราด':'ตราด', 'ตราด\xa0':'ตราด',
#                                      'ตาก': 'ตาก',  'ตากใบ': 'ตาก',  'ต่างจังหวัด':'ไม่ระบุ','ทุ่งเสลี่ยม':'ไม่ระบุ' ,
#                                       'ท้ายบ้าน':'ไม่ระบุ',  'ธารโต':'ไม่ระบุ',  'นคนปฐม':'นครปฐม', 'นคปฐม':'นครปฐม', 
#                                      'นครนปฐม':'นครปฐม',  'นครนาชสีมา':'นครราชสีมา', 'นครนายก':'นครนายก' ,'นครปฐม':'นครปฐม',
#                                      'นครปฐม\xa0':'นครปฐม', 'นครปบม':'นครพนม', 'นครพนม':'นครพนม', 'นครพนม\xa0':'นครพนม',
#                                      'นครยายก':'นครนายก', 'นครราขสีมา':'นครราชสีมา', 'นครราชธานี':'นครราชสีมา', 'นครราชศรีมา':'นครราชสีมา',
#                                      'นครราชสสีมา':'นครราชสีมา', 'นครราชสีมา':'นครราชสีมา', 'นครราชสีมา ลพบุรี':'ไม่ระบุ', 'นครราชสีมา\xa0':'นครราชสีมา',
#                                      'นครศรธรรมราช':'นครศรีธรรมราช', 'นครศรี':'นครศรีธรรมราช', 'นครศรีธรมมราช':'นครศรีธรรมราช', 'นครศรีธรมราช':'นครศรีธรรมราช',
#                                      'นครศรีธรรมราข':'นครศรีธรรมราช', 'นครศรีธรรมราช':'นครศรีธรรมราช', 'นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช',
#                                      'นครศร๊ธรรมราช':'นครศรีธรรมราช', 'นครศร๊ะรรมราช':'นครศรีธรรมราช', 'นครสรรค์':'นครสวรรค์', 'นครสรีธรรมราช':'นครศรีธรรมราช',
#                                      'นครสวรรค':'นครสวรรค์', 'นครสวรรค์':'นครสวรรค์', 'นครสวรรค์\xa0':'นครสวรรค์', 'นครสีธรรมราช':'นครศรีธรรมราช',
#                                     'นครฯ': 'ไม่ระบุ', 'นคราชสีมา': 'นครราชสีมา', 'นครีศรีธรรมราช': 'นครศรีธรรมราช', 'นตรนายก': 'นครนายก', 
#                                     'นตรปฐม': 'นครปฐม',  'นนทบุรี': 'นนทบุรี', 'นนทบุรี\xa0': 'นนทบุรี', 'นนทบุุรี':'นนทบุรี',
#                                     'นนทุบรี': 'นนทบุรี', 'นนทุรี': 'นนทบุรี', 'นนมบุรี': 'นนทบุรี', 'นรศรีธรรมราช': 'นครศรีธรรมราช',
#                                     'นราธิวาส': 'นราธิวาส', 'นราธิวาส\u200b': 'นราธิวาส', 'นราธฺวาส': 'นราธิวาส', 'นอกเขต': 'นราธิวาส',
#                                     'นาราธิวาส': 'นราธิวาส', 'นาวัง': 'ไม่ระบุ', 'น่าน': 'น่าน', 'น่าน/ฉะเชิงเทรา': 'ไม่ระบุ', 
#                                     'บางกรวย': 'ไม่ระบุ', 'บางกะปิ': 'ไม่ระบุ', 'บางนา': 'ไม่ระบุ', 'บางปะอิน': 'ไม่ระบุ',
#                                     'บางละมุง': 'ไม่ระบุ', 'บางศรีเมือง': 'ไม่ระบุ', 'บางเพียง': 'ไม่ระบุ', 'บึงกาฬ': 'บึงกาฬ',
#                                     'บึงโขงหลง': 'ไม่ระบุ', 'บุรีรัมภ์': 'บุรีรัมย์', 'บุรีรัมย์': 'บุรีรัมย์', 'บุรีรัมย์\xa0': 'บุรีรัมย์',
#                                     'บุรีรัยม์': 'บุรีรัมย์', 'บุรีรีมย์': 'บุรีรัมย์', 'บ้านหลวง': 'ไม่ระบุ', 'ปจ': 'ไม่ระบุ',
#                                     'ปทึมธานี': 'ปทุมธานี', 'ปทุทธานี': 'ปทุมธานี', 'ปทุมฑานี': 'ปทุมธานี', 'ปทุมทานี': 'ปทุมธานี',
#                                     'ปทุมธาน': 'ปทุมธานี', 'ปทุมธานี': 'ปทุมธานี', 'ปทุมธานี.':'ปทุมธานี', 'ปทุมธานี\xa0':'ปทุมธานี',
#                                     'ปทุมธานีี':'ปทุมธานี', 'ปทุมาธานี':'ปทุมธานี', 'ปทุุมธานี':'ปทุมธานี', 'ปธุมธานี':'ปทุมธานี',
#                                     'ปมุมธานี':'ปทุมธานี', 'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์', 'ประจวบ':'ประจวบคีรีขันธ์', 'ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์',
#                                     'ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์', 'ประจวบคีรีขัน':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์',
#                                     'ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์',
#                                     'ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์', 'ประจวบฯ':'ประจวบคีรีขันธ์', 'ประทุมธานี':'ปทุมธานี',
#                                     'ประเทศกัมพูชา':'ไม่ระบุ', 'ปราจีนบุรี': 'ปราจีนบุรี', 'ปราจีบุรี': 'ปราจีนบุรี', 'ปลวกแดง': 'ไม่ระบุ',
#                                     'ปลายพระยา': 'ไม่ระบุ', 'ปอยเปต': 'ไม่ระบุ', 'ปัตตนรี': 'ปัตตานี', 'ปัตตานนี': 'ปัตตานี',
#                                     'ปัตตานี': 'ปัตตานี','ปัตตานีี': 'ปัตตานี', 'ปัตาตานี': 'ปัตตานี', 'ปัว': 'ไม่ระบุ',
#                                     'ปััตตานี': 'ปัตตานี', 'ปุทมธานี': 'ปทุมธานี', 'ป่าโมก': 'ไม่ระบุ', 'พม่า': 'ไม่ระบุ',
#                                     'พรหมพิราม': 'ไม่ระบุ', 'พระนครศรียุธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุทธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุทยา': 'พระนครศรีอยุธยา',
#                                     'พระนครศรีอยุธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุธยา\xa0': 'พระนครศรีอยุธยา', 'พะเยา': 'พะเยา', 'พังงา':'พังงา',
#                                     'พัทยา': 'ไม่ระบุ', 'พัทลุง': 'พัทลุง', 'พัทลุุง': 'พัทลุง','มหาสาคาม' : 'มหาสารคาม',
#                                     'มหาสารคาม' : 'มหาสารคาม', 'มาเลเซีย' : 'ไม่ระบุ', 'มุกดาหาร' : 'มุกดาหาร', 'มุกาดหาร' : 'มุกดาหาร',
#                                     'ยะลา' : 'ยะลา', 'ยานนาวา' : 'ไม่ระบุ', 'ยโสธร' : 'ยโสธร', 'ร.จ.จ.นราธิวาส' : 'นราธิวาส',
#                                     'รอ' : 'ระยอง', 'ระนอง' : 'ระนอง', 'ระบุ' : 'ไม่ระบุ', 'ระยอง' : 'ระยอง',
#                                     'ระยอง\xa0': 'ระยอง', 'ระอยง' : 'ระยอง', 'ราชบบุรี' : 'ราชบุรี', 'ราชบุรี' : 'ราชบุรี',
#                                     'ราชบุรีี' : 'ราชบุรี', 'ราชบุรี\u200b': 'ราชบุรี', 'ราชุรี' : 'ราชบุรี', 'ราชเทวี' : 'ไม่ระบุ',
#                                     'ร้องกวาง' : 'ไม่ระบุ', 'ร้อยเอ็ด' : 'ร้อยเอ็ด', 'ลบุรี' : 'ลพบุรี', 'ลพบุรี' : 'ลพบุรี',
#                                     'ลพบุรี.' : 'ลพบุรี', 'ลพบุรี\xa0' : 'ลพบุรี', 'ลอง' : 'ไม่ระบุ', 'ลาดกระบัง' : 'ไม่ระบุ',
#                                     'ลาดพร้าว' : 'ไม่ระบุ', 'ลาว' : 'ไม่ระบุ', 'ลำปาง' : 'ลำปาง', 'ลำพูน' : 'ลำพูน',
#                                     'ลำพูน\u200b': 'ลำพูน', 'ลำพููน' : 'ลำพูน', 'ลำลูกกา' : 'ไม่ระบุ', 'วังชิ้น' : 'ไม่ระบุ',
#                                     'วังทอง' : 'ไม่ระบุ', 'วิเศษชัยชาญ' : 'ไม่ระบุ', 'ศรีษะสะเกษ' : 'ศรีสะเกษ', 'ศรีษะเกษ' : 'ศรีสะเกษ',
#                                     'ศรีสระเกษ' : 'ศรีสะเกษ', 'ศรีสะเกษ' : 'ศรีสะเกษ', 'ศีรสะเกษ' : 'ศรีสะเกษ', 'สกลนคร' : 'สกลนคร',
#                                     'สครสวรรค์' : 'นครสวรรค์', 'สงขลา' : 'สงขลา', 'สงขลา\u200b': 'สงขลา', 'สตูล' : 'สตูล',
#                                     'สถานที่ทำงาน' : 'ไม่ระบุ', 'สพรรณบุรี' : 'สุพรรณบุรี', 'สมถทรปราการ' : 'สมุทรปราการ', 'สมทรสงคราม' : 'สมุทรสงคราม',
#                                     'สมทรสาคร' : 'สมุทรสาคร', 'สมุครปราการ' : 'สมุทรปราการ', 'สมุครสาคร' : 'สมุทรสาคร', 'สมุท' : 'ไม่ระบุ',
#                                     'สมุทปราการ' : 'สมุทรปราการ', 'สมุทรปรากร' : 'สมุทรปราการ', 'สมุทรปรากรร' : 'สมุทรปราการ', 'สมุทรปรากา' : 'สมุทรปราการ',
#                                     'สมุทรปราการ' : 'สมุทรปราการ', 'สมุทรปราการ\xa0' : 'สมุทรสงคราม', 'สมุทรศาคร' : 'สมุทรสาคร', 'สมุทรสงคราม' : 'สมุทรสงคราม',
#                                     'สมุทรสาคร' : 'สมุทรสาคร', 'สมุทรสาคร\xa0' : 'สมุทรสาคร', 'สมุทรสาคา' : 'สมุทรสาคร', 'สมุทรสาคาร' : 'สมุทรสาคร',
#                                     'สมุทรสาทร' : 'สมุทรสาคร', 'สมุทรสารคร' : 'สมุทรสาคร', 'สมุทราปราการ' : 'สมุทรปราการ', 'สมุทราสาคร' : 'สมุทรสาคร',
#                                     'สมุทสงคราม' : 'สมุทรสงคราม', 'สมุทสาคร' : 'สมุทรสาคร', 'สมุย' : 'ไม่ระบุ', 'สมุุทรปราการ' : 'สมุทรปราการ',
#                                     'สมุุทรสงคราม' : 'สมุทรสงคราม', 'สมุุทรสาคร' : 'สมุทรสาคร', 'สระก้ว' : 'สระแก้ว', 'สระบุรี' : 'สระบุรี',
#                                     'สระบุรี\xa0': 'สระบุรี', 'สระแก้ว' : 'สระแก้ว', 'สรินทร์' : 'สุรินทร์', 'สวิสเซอร์แลนด์' : 'ไม่ระบุ',
#                                     'สอง' : 'ไม่ระบุ', 'สองแคว':'ไม่ระบุ', 'สะพานสูง' : 'ไม่ระบุ', 'สะแก้ว' : 'สระแก้ว',
#                                     'สัตหีบ' : 'ไม่ระบุ', 'สัมผัสผู้ป่วยยืนยัน COVID20': 'ไม่ระบุ', 'สามุทรสาคร' : 'สมุทรสาคร', 'สารคาม' : 'มหาสารคาม',
#                                     'สารภี' : 'ไม่ระบุ', 'สิงห์บุรี' : 'สิงห์บุรี', 'สิงห์บุรี\xa0' : 'สิงห์บุรี', 'สุทรปราการ' : 'สมุทรปราการ',
#                                     'สุพรรญบุรี' : 'สุพรรณบุรี', 'สุพรรณบุรั' : 'สุพรรณบุรี', 'สุพรรณบุรี' : 'สุพรรณบุรี', 'สุพรรณบุรี\xa0':'สุพรรณบุรี',
#                                     'สุมทรปราการ' : 'สมุทรปราการ', 'สุมทรสาคร' : 'สมุทรสาคร', 'สุมุทรปราการ' : 'สมุทรปราการ', 'สุมุทรสาคร' : 'สมุทรสาคร',
#                                     'สุระบุรี' : 'สระบุรี', 'สุราษ' : 'สุราษฎร์ธานี', 'สุราษฎณ์ธานี' : 'สุราษฎร์ธานี', 'สุราษฎธานี' : 'สุราษฎร์ธานี',
#                                     'สุราษฎร์' : 'สุราษฎร์ธานี', 'สุราษฎร์ธานี' : 'สุราษฎร์ธานี', 'สุราษฎร์ฯ' : 'สุราษฎร์ธานี', 'สุราษฎร์์ธานี' : 'สุราษฎร์ธานี',
#                                     'สุราษฎ์ธานี' : 'สุราษฎร์ธานี', 'สุราษฏร์ธานี' : 'สุราษฎร์ธานี', 'สุราษธานี' : 'สุราษฎร์ธานี', 'สุราษร์ฎธานี': 'สุราษฎร์ธานี',
#                                     'สุราษร์ธานี' : 'สุราษฎร์ธานี', 'สุราษฯ' : 'สุราษฎร์ธานี', 'สุรินทรื' : 'สุรินทร์', 'สุรินทร์' : 'สุรินทร์',
#                                     'สุรินทร์ 32150' : 'สุรินทร์', 'สุรินทร์,รีสะเกษ':'ไม่ระบุ', 'สุรินทร์\xa0' : 'สุรินทร์', 'สุริมทร์' : 'สุรินทร์',
#                                     'สุริะแก้ว' : 'สระแก้ว', 'สุวรรณภูมิ' : 'ไม่ระบุ', 'สุุพรรณบุรี' : 'สุพรรณบุรี', 'สุุราษฎร์ธานี' : 'สุราษฎร์ธานี',
#                                     'สุุราษฏร์ธานี' : 'สุราษฎร์ธานี', 'สุุราษฯ' : 'สุราษฎร์ธานี', 'สุุรินทร์' : 'สุรินทร์', 'สุุุโขทัย' : 'สุโขทัย',
#                                     'สุโขทับ' : 'สุโขทัย', 'สุโขทัย' : 'สุโขทัย', 'สุโขทัย\xa0' : 'สุโขทัย', 'สูงเม่น' : 'ไม่ระบุ',
#                                     'เพขรบุรี':'เพชรบุรี', 'เพขรบูรณื': 'เพชรบูรณ์', 'เพขรบูรณ์':'เพชรบูรณ์',  'เพชรบุรณ์':'เพชรบูรณ์',
#                                     'เพชรบุรี':'เพชรบุรี', 'เพชรบุรึ':'เพชรบุรี', 'เพชรบุุรี':'เพชรบุรี', 'เพชรบุูรณ์':'เพชรบูรณ์',
#                                     'เพชรบูรณ์':'เพชรบูรณ์', 'เพชรบูรณ์\xa0':'เพชรบูรณ์',  'เพชรบูร์':'เพชรบูรณ์', 'เพชรบููรณ์':'เพชรบูรณ์',
#                                     'เมือง':'ไม่ระบุ', 'เมืองตาก':'ตาก', 'เมืองน่าน':'น่าน', 'เมืองปัตตานี':'ไม่ระบุ',
#                                     'เรือ':'ไม่ระบุ', 'เลย':'เลย',  'เลย\xa0':'เลย',  'เวียงจันทร์':'ไม่ระบุ',
#                                     'เวียงสา':'ไม่ระบุ', 'แม่ทะ':'ไม่ระบุ', 'แพร่':'แพร่', 'แม่ฮ่องสอน':'แม่ฮ่องสอน',
#                                     'แล้วป่วย':'ไม่ระบุ', 'โพธิ์ทอง':'ไม่ระบุ', 'ไชโย':'ไม่ระบุ', 'ไม่มีชื่อหอพัก':'ไม่ระบุ',
#                                     'ไม่ระบุ':'ไม่ระบุ', 'หนวงบัวลำภู': 'หนองบัวลำภู', 'หนองคาย': 'หนองคาย', 'หนองงคาย': 'หนองคาย',
#                                     'หนองบัวภู': 'หนองบัวลำภู', 'หนองบัวลำพูน': 'หนองบัวลำภู', 'หนองบัวลำภู': 'หนองบัวลำภู', 'หนองบัวลําภู': 'หนองบัวลำภู',
#                                     'หนองบััวลำภู': 'หนองบัวลำภู', 'หนองม่วงไข่': 'ไม่ระบุ', 'หนอบัวลำภู': 'หนองบัวลำภู', 'หลายจังหวัด': 'ไม่ระบุ',
#                                     'หัวหิน': 'ไม่ระบุ', 'ห้วยขวาง': 'ไม่ระบุ', 'อยุทธยา': 'พระนครศรีอยุธยา', 'อยุธยา': 'พระนครศรีอยุธยา',
#                                     'อยุุธยา': 'พระนครศรีอยุธยา', 'อำนาจเจริญ':  'อำนาจเจริญ', 'อำนาจเจิญ':  'อำนาจเจริญ', 'อำนาญเจริญ':  'อำนาจเจริญ',
#                                     'อำนาเจริญ':  'อำนาจเจริญ', 'อิสราเอล':  'ไม่ระบุ', 'อุดธานี': 'อุดรธานี', 'อุดร': 'อุดรธานี',
#                                     'อุดรธาณี': 'อุดรธานี', 'อุดรธานี': 'อุดรธานี', 'อุดรธานี\xa0': 'อุดรธานี', 'อุดรธานีี': 'อุดรธานี',
#                                     'อุดรราชธานี': 'อุดรธานี', 'อุตรดิตถ์': 'อุตรดิตถ์', 'อุตรดิตถ์\xa0': 'อุตรดิตถ์', 'อุตรดิตถ์์': 'อุตรดิตถ์',
#                                     'อุตรดิษถ์': 'อุตรดิตถ์', 'อุตรดิิตถ์': 'อุตรดิตถ์', 'อุตรติดถ์': 'อุตรดิตถ์', 'อุทัยธานี': 'อุทัยธานี',
#                                     'อุทัยานี': 'อุทัยธานี', 'อุบลราขธานี': 'อุบลราชธานี', 'อุบลราชธานี': 'อุบลราชธานี', 'อุบลราชธานี\xa0': 'อุบลราชธานี',
#                                     'อุุครดิตถ์': 'อุตรดิตถ์', 'อุุดรธาน': 'อุดรธานี', 'อุุดรธานี': 'อุดรธานี', 'อุุตรดิตถ์': 'อุตรดิตถ์',
#                                     'อุุทัยธานี': 'อุทัยธานี', 'อุุบลราชธานี': 'อุบลราชธานี', 'อ่งทอง': 'อ่างทอง', 'อ่างทอง': 'อ่างทอง',
#                                     'อ่างทอง\xa0': 'อ่างทอง', 'อํานาจเจริญ': 'อํานาจเจริญ', 'เชิงเทรา': 'ฉะเชิงเทรา', 'เชียงราย': 'เชียงราย',
#                                     'เชียงใหม่': 'เชียงใหม่', 'เชียรใหญ่': 'เชียงใหม่', 'เชีียงราย': 'เชียงราย', 'เชีียงใหม่': 'เชียงราย', 'เด่นชัย':'ไม่ระบุ',
#                                     'พัังงา':'พังงา','พิจิตร':'พิจิตร','พิษณุโลก': 'พิษณุโลก','พิษณุโลก\xa0': 'พิษณุโลก',
#                                     'พิษณูโลก': 'พิษณุโลก','ฟินแลนด์': 'ไม่ระบุ','ภาษีเจริญ': 'ไม่ระบุ','ภุเก็ต': 'ภุเก็ต',
#                                     'ภูุเก็ต': 'ภุเก็ต','ภููเก็ต': 'ภุเก็ต','ภูเก็ต': 'ภุเก็ต','ภูเก็็ต': 'ภุเก็ต','ภูเพียง': 'ภุเก็ต'})
# re_name #แสดงผล

# %%
re_name1=show_data1.replace({'\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',  'USA':'ไม่ระบุ', 'nan':'ไม่ระบุ', '\xa0กาญจนบุรี':'กาญจนบุรี', 
                                    '\xa0ชลบุรี':'ชลบุรี', '\xa0ตราด':'ตราด',  '\xa0นครปฐม': 'นครปฐม', '\xa0สมุทรสงคราม':'สมุทรสงคราม',
                                    '\xa0สมุทรสาคร':'สมุทรสาคร',  '\xa0อุทัยธานี': 'อุทัยธานี', 'กทม':'กรุงเทพมหานคร',  'กทม.':'กรุงเทพมหานคร',
                                     'กบินทร์บุรี':'ไม่ระบุ',  'กระบี่': 'กระบี่', 'กระบี่ี่':'กระบี่',  'กรุงเทพ':'กรุงเทพมหานคร',
                                     'กรุงเทพมหานคร': 'กรุงเทพมหานคร', 'กรุงเทพมหานคร.': 'กรุงเทพมหานคร',  'กรุงเทพมหานคร. / พระนครศรีอยุธยา':'ไม่ระบุ', 'กรุงเทพมหานคร. / ศรีสะเกษ':'ไม่ระบุ',
                                     'กรุงเทพฯ': 'กรุงเทพมหานคร',  'กะทู้':'ไม่ระบุ', 'กัมพูชา':'ไม่ระบุ',  'กาญจนบุรี':'กาญจนบุรี',
                                     'กาญจบุรี':'กาญจนบุรี',  'กาญนบุรี':'กาญจนบุรี', 'กาฬสิน': 'กาฬสินธุ์',  'กาฬสินธิ์': 'กาฬสินธุ์',
                                     'กาฬสินธุ์': 'กาฬสินธุ์', 'กาฬสินธุ์\xa0': 'กาฬสินธุ์',  'กาฬสินธ์': 'กาฬสินธุ์', 'กำเพงเพชร':'กำแพงเพชร',
                                     'กำแพง':'กำแพงเพชร', 'กำแพงเพชร':'กำแพงเพชร',  'กำแพงเพชร\xa0': 'กำแพงเพชร',  'กําแพงเพชร': 'กำแพงเพชร',
                                     'ขอนแก่น':'ขอนแก่น',  'ขอนแก่น\xa0': 'ขอนแก่น',  'ขอนแก่่น': 'ขอนแก่น',  'ขัยนาท':'ชัยนาท',
                                     'ขัยภูมิ':'ชัยภูมิ', 'ขานุวรลักษณ์บุรี':'ไม่ระบุ', 'คนไทยเดินทางกลับจากต่างประเทศ':'ไม่ระบุ',  'คลองเตย':'ไม่ระบุ',
                                     'จ.กรุงเทพมหานคร': 'กรุงเทพมหานคร', 'จ.ภูเก็ต':'ภูเก็ต',  'จ.ราชบุรี': 'ราชบุรี',  'จ.สุราษฎร์ธานี': 'สุราษฎร์ธานี',
                                     'จังหวัดสมุทรสาคร': 'สมุทรสาคร',  'จันทบุรี': 'จันทบุรี', 'ฉะเชองเทราร': 'ฉะเชิงเทรา',  'ฉะเชิงเทรา': 'ฉะเชิงเทรา',
                                     'ชมพร':'ชุมพร',  'ชลบุรี': 'ชลบุรี',  'ชลบุรี\t': 'ชลบุรี', 'ชลบุรี\xa0': 'ชลบุรี',
                                     'ชลบุุรี':'ชลบุรี', 'ชอนแก่น':'ขอนแก่น',  'ชัยนาถ': 'ชัยนาท',  'ชัยนาท': 'ชัยนาท',
                                     'ชัยบาดาล':'ไม่ระบุ', 'ชัยภูมิ': 'ชัยภูมิ',  'ชัยภูมิ\xa0': 'ชัยภูมิ', 'ชุมพร':'ชุมพร',
                                     'ชุุมพร':'ชุมพร',  'ชุุุมพร':'ชุมพร', 'ดอนมดแดง':'ไม่ระบุ',  'ดินแดง':'ไม่ระบุ',
                                     'ตรัง':'ตรัง',  'ตรััง':'ตรัง', 'ตราด':'ตราด', 'ตราด\xa0':'ตราด',
                                     'ตาก': 'ตาก',  'ตากใบ': 'ตาก',  'ต่างจังหวัด':'ไม่ระบุ','ทุ่งเสลี่ยม':'ไม่ระบุ' ,
                                      'ท้ายบ้าน':'ไม่ระบุ',  'ธารโต':'ไม่ระบุ',  'นคนปฐม':'นครปฐม', 'นคปฐม':'นครปฐม', 
                                     'นครนปฐม':'นครปฐม',  'นครนาชสีมา':'นครราชสีมา', 'นครนายก':'นครนายก' ,'นครปฐม':'นครปฐม',
                                     'นครปฐม\xa0':'นครปฐม', 'นครปบม':'นครพนม', 'นครพนม':'นครพนม', 'นครพนม\xa0':'นครพนม',
                                     'นครยายก':'นครนายก', 'นครราขสีมา':'นครราชสีมา', 'นครราชธานี':'นครราชสีมา', 'นครราชศรีมา':'นครราชสีมา',
                                     'นครราชสสีมา':'นครราชสีมา', 'นครราชสีมา':'นครราชสีมา', 'นครราชสีมา ลพบุรี':'ไม่ระบุ', 'นครราชสีมา\xa0':'นครราชสีมา',
                                     'นครศรธรรมราช':'นครศรีธรรมราช', 'นครศรี':'นครศรีธรรมราช', 'นครศรีธรมมราช':'นครศรีธรรมราช', 'นครศรีธรมราช':'นครศรีธรรมราช',
                                     'นครศรีธรรมราข':'นครศรีธรรมราช', 'นครศรีธรรมราช':'นครศรีธรรมราช', 'นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช',
                                     'นครศร๊ธรรมราช':'นครศรีธรรมราช', 'นครศร๊ะรรมราช':'นครศรีธรรมราช', 'นครสรรค์':'นครสวรรค์', 'นครสรีธรรมราช':'นครศรีธรรมราช',
                                     'นครสวรรค':'นครสวรรค์', 'นครสวรรค์':'นครสวรรค์', 'นครสวรรค์\xa0':'นครสวรรค์', 'นครสีธรรมราช':'นครศรีธรรมราช',
                                    'นครฯ': 'ไม่ระบุ', 'นคราชสีมา': 'นครราชสีมา', 'นครีศรีธรรมราช': 'นครศรีธรรมราช', 'นตรนายก': 'นครนายก', 
                                    'นตรปฐม': 'นครปฐม',  'นนทบุรี': 'นนทบุรี', 'นนทบุรี\xa0': 'นนทบุรี', 'นนทบุุรี':'นนทบุรี'})
re_name1
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# ...

# %%
re_name2=re_name1.replace({'นนทุบรี': 'นนทบุรี', 'นนทุรี': 'นนทบุรี', 'นนมบุรี': 'นนทบุรี', 'นรศรีธรรมราช': 'นครศรีธรรมราช',
                                    'นราธิวาส': 'นราธิวาส', 'นราธิวาส\u200b': 'นราธิวาส', 'นราธฺวาส': 'นราธิวาส', 'นอกเขต': 'นราธิวาส',
                                    'นาราธิวาส': 'นราธิวาส', 'นาวัง': 'ไม่ระบุ', 'น่าน': 'น่าน', 'น่าน/ฉะเชิงเทรา': 'ไม่ระบุ', 
                                    'บางกรวย': 'ไม่ระบุ', 'บางกะปิ': 'ไม่ระบุ', 'บางนา': 'ไม่ระบุ', 'บางปะอิน': 'ไม่ระบุ',
                                    'บางละมุง': 'ไม่ระบุ', 'บางศรีเมือง': 'ไม่ระบุ', 'บางเพียง': 'ไม่ระบุ', 'บึงกาฬ': 'บึงกาฬ',
                                    'บึงโขงหลง': 'ไม่ระบุ', 'บุรีรัมภ์': 'บุรีรัมย์', 'บุรีรัมย์': 'บุรีรัมย์', 'บุรีรัมย์\xa0': 'บุรีรัมย์',
                                    'บุรีรัยม์': 'บุรีรัมย์', 'บุรีรีมย์': 'บุรีรัมย์', 'บ้านหลวง': 'ไม่ระบุ', 'ปจ': 'ไม่ระบุ',
                                    'ปทึมธานี': 'ปทุมธานี', 'ปทุทธานี': 'ปทุมธานี', 'ปทุมฑานี': 'ปทุมธานี', 'ปทุมทานี': 'ปทุมธานี',
                                    'ปทุมธาน': 'ปทุมธานี', 'ปทุมธานี': 'ปทุมธานี', 'ปทุมธานี.':'ปทุมธานี', 'ปทุมธานี\xa0':'ปทุมธานี',
                                    'ปทุมธานีี':'ปทุมธานี', 'ปทุมาธานี':'ปทุมธานี', 'ปทุุมธานี':'ปทุมธานี', 'ปธุมธานี':'ปทุมธานี',
                                    'ปมุมธานี':'ปทุมธานี', 'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์', 'ประจวบ':'ประจวบคีรีขันธ์', 'ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์',
                                    'ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์', 'ประจวบคีรีขัน':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์',
                                    'ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์', 'ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์',
                                    'ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์', 'ประจวบฯ':'ประจวบคีรีขันธ์', 'ประทุมธานี':'ปทุมธานี',
                                    'ประเทศกัมพูชา':'ไม่ระบุ', 'ปราจีนบุรี': 'ปราจีนบุรี', 'ปราจีบุรี': 'ปราจีนบุรี', 'ปลวกแดง': 'ไม่ระบุ',
                                    'ปลายพระยา': 'ไม่ระบุ', 'ปอยเปต': 'ไม่ระบุ', 'ปัตตนรี': 'ปัตตานี', 'ปัตตานนี': 'ปัตตานี',
                                    'ปัตตานี': 'ปัตตานี','ปัตตานีี': 'ปัตตานี', 'ปัตาตานี': 'ปัตตานี', 'ปัว': 'ไม่ระบุ',
                                    'ปััตตานี': 'ปัตตานี', 'ปุทมธานี': 'ปทุมธานี', 'ป่าโมก': 'ไม่ระบุ', 'พม่า': 'ไม่ระบุ',
                                    'พรหมพิราม': 'ไม่ระบุ', 'พระนครศรียุธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุทธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุทยา': 'พระนครศรีอยุธยา',
                                    'พระนครศรีอยุธยา': 'พระนครศรีอยุธยา', 'พระนครศรีอยุธยา\xa0': 'พระนครศรีอยุธยา', 'พะเยา': 'พะเยา', 'พังงา':'พังงา',
                                    'พัทยา': 'ไม่ระบุ', 'พัทลุง': 'พัทลุง', 'พัทลุุง': 'พัทลุง','มหาสาคาม' : 'มหาสารคาม',
                                    'มหาสารคาม' : 'มหาสารคาม', 'มาเลเซีย' : 'ไม่ระบุ', 'มุกดาหาร' : 'มุกดาหาร', 'มุกาดหาร' : 'มุกดาหาร',
                                    'ยะลา' : 'ยะลา', 'ยานนาวา' : 'ไม่ระบุ', 'ยโสธร' : 'ยโสธร', 'ร.จ.จ.นราธิวาส' : 'นราธิวาส',
                                    'รอ' : 'ระยอง', 'ระนอง' : 'ระนอง', 'ระบุ' : 'ไม่ระบุ', 'ระยอง' : 'ระยอง',
                                    'ระยอง\xa0': 'ระยอง', 'ระอยง' : 'ระยอง', 'ราชบบุรี' : 'ราชบุรี', 'ราชบุรี' : 'ราชบุรี',
                                    'ราชบุรีี' : 'ราชบุรี', 'ราชบุรี\u200b': 'ราชบุรี', 'ราชุรี' : 'ราชบุรี', 'ราชเทวี' : 'ไม่ระบุ',
                                    'ร้องกวาง' : 'ไม่ระบุ', 'ร้อยเอ็ด' : 'ร้อยเอ็ด', 'ลบุรี' : 'ลพบุรี', 'ลพบุรี' : 'ลพบุรี',
                                    'ลพบุรี.' : 'ลพบุรี', 'ลพบุรี\xa0' : 'ลพบุรี', 'ลอง' : 'ไม่ระบุ', 'ลาดกระบัง' : 'ไม่ระบุ',
                                    'ลาดพร้าว' : 'ไม่ระบุ', 'ลาว' : 'ไม่ระบุ', 'ลำปาง' : 'ลำปาง', 'ลำพูน' : 'ลำพูน',
                                    'ลำพูน\u200b': 'ลำพูน', 'ลำพููน' : 'ลำพูน', 'ลำลูกกา' : 'ไม่ระบุ', 'วังชิ้น' : 'ไม่ระบุ'})
re_name2
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# ...

# %%
re_name3=re_name2.replace({'วังทอง' : 'ไม่ระบุ', 'วิเศษชัยชาญ' : 'ไม่ระบุ', 'ศรีษะสะเกษ' : 'ศรีสะเกษ', 'ศรีษะเกษ' : 'ศรีสะเกษ',
                                    'ศรีสระเกษ' : 'ศรีสะเกษ', 'ศรีสะเกษ' : 'ศรีสะเกษ', 'ศีรสะเกษ' : 'ศรีสะเกษ', 'สกลนคร' : 'สกลนคร',
                                    'สครสวรรค์' : 'นครสวรรค์', 'สงขลา' : 'สงขลา', 'สงขลา\u200b': 'สงขลา', 'สตูล' : 'สตูล',
                                    'สถานที่ทำงาน' : 'ไม่ระบุ', 'สพรรณบุรี' : 'สุพรรณบุรี', 'สมถทรปราการ' : 'สมุทรปราการ', 'สมทรสงคราม' : 'สมุทรสงคราม',
                                    'สมทรสาคร' : 'สมุทรสาคร', 'สมุครปราการ' : 'สมุทรปราการ', 'สมุครสาคร' : 'สมุทรสาคร', 'สมุท' : 'ไม่ระบุ',
                                    'สมุทปราการ' : 'สมุทรปราการ', 'สมุทรปรากร' : 'สมุทรปราการ', 'สมุทรปรากรร' : 'สมุทรปราการ', 'สมุทรปรากา' : 'สมุทรปราการ',
                                    'สมุทรปราการ' : 'สมุทรปราการ', 'สมุทรปราการ\xa0' : 'สมุทรสงคราม', 'สมุทรศาคร' : 'สมุทรสาคร', 'สมุทรสงคราม' : 'สมุทรสงคราม',
                                    'สมุทรสาคร' : 'สมุทรสาคร', 'สมุทรสาคร\xa0' : 'สมุทรสาคร', 'สมุทรสาคา' : 'สมุทรสาคร', 'สมุทรสาคาร' : 'สมุทรสาคร',
                                    'สมุทรสาทร' : 'สมุทรสาคร', 'สมุทรสารคร' : 'สมุทรสาคร', 'สมุทราปราการ' : 'สมุทรปราการ', 'สมุทราสาคร' : 'สมุทรสาคร',
                                    'สมุทสงคราม' : 'สมุทรสงคราม', 'สมุทสาคร' : 'สมุทรสาคร', 'สมุย' : 'ไม่ระบุ', 'สมุุทรปราการ' : 'สมุทรปราการ',
                                    'สมุุทรสงคราม' : 'สมุทรสงคราม', 'สมุุทรสาคร' : 'สมุทรสาคร', 'สระก้ว' : 'สระแก้ว', 'สระบุรี' : 'สระบุรี',
                                    'สระบุรี\xa0': 'สระบุรี', 'สระแก้ว' : 'สระแก้ว', 'สรินทร์' : 'สุรินทร์', 'สวิสเซอร์แลนด์' : 'ไม่ระบุ',
                                    'สอง' : 'ไม่ระบุ', 'สองแคว':'ไม่ระบุ', 'สะพานสูง' : 'ไม่ระบุ', 'สะแก้ว' : 'สระแก้ว',
                                    'สัตหีบ' : 'ไม่ระบุ', 'สัมผัสผู้ป่วยยืนยัน COVID20': 'ไม่ระบุ', 'สามุทรสาคร' : 'สมุทรสาคร', 'สารคาม' : 'มหาสารคาม',
                                    'สารภี' : 'ไม่ระบุ', 'สิงห์บุรี' : 'สิงห์บุรี', 'สิงห์บุรี\xa0' : 'สิงห์บุรี', 'สุทรปราการ' : 'สมุทรปราการ',
                                    'สุพรรญบุรี' : 'สุพรรณบุรี', 'สุพรรณบุรั' : 'สุพรรณบุรี', 'สุพรรณบุรี' : 'สุพรรณบุรี', 'สุพรรณบุรี\xa0':'สุพรรณบุรี',
                                    'สุมทรปราการ' : 'สมุทรปราการ', 'สุมทรสาคร' : 'สมุทรสาคร', 'สุมุทรปราการ' : 'สมุทรปราการ', 'สุมุทรสาคร' : 'สมุทรสาคร',
                                    'สุระบุรี' : 'สระบุรี', 'สุราษ' : 'สุราษฎร์ธานี', 'สุราษฎณ์ธานี' : 'สุราษฎร์ธานี', 'สุราษฎธานี' : 'สุราษฎร์ธานี',
                                    'สุราษฎร์' : 'สุราษฎร์ธานี', 'สุราษฎร์ธานี' : 'สุราษฎร์ธานี', 'สุราษฎร์ฯ' : 'สุราษฎร์ธานี', 'สุราษฎร์์ธานี' : 'สุราษฎร์ธานี',
                                    'สุราษฎ์ธานี' : 'สุราษฎร์ธานี', 'สุราษฏร์ธานี' : 'สุราษฎร์ธานี', 'สุราษธานี' : 'สุราษฎร์ธานี', 'สุราษร์ฎธานี': 'สุราษฎร์ธานี',
                                    'สุราษร์ธานี' : 'สุราษฎร์ธานี', 'สุราษฯ' : 'สุราษฎร์ธานี', 'สุรินทรื' : 'สุรินทร์', 'สุรินทร์' : 'สุรินทร์',
                                    'สุรินทร์ 32150' : 'สุรินทร์', 'สุรินทร์,รีสะเกษ':'ไม่ระบุ', 'สุรินทร์\xa0' : 'สุรินทร์', 'สุริมทร์' : 'สุรินทร์',
                                    'สุริะแก้ว' : 'สระแก้ว', 'สุวรรณภูมิ' : 'ไม่ระบุ', 'สุุพรรณบุรี' : 'สุพรรณบุรี', 'สุุราษฎร์ธานี' : 'สุราษฎร์ธานี',
                                    'สุุราษฏร์ธานี' : 'สุราษฎร์ธานี', 'สุุราษฯ' : 'สุราษฎร์ธานี', 'สุุรินทร์' : 'สุรินทร์', 'สุุุโขทัย' : 'สุโขทัย',
                                    'สุโขทับ' : 'สุโขทัย', 'สุโขทัย' : 'สุโขทัย', 'สุโขทัย\xa0' : 'สุโขทัย', 'สูงเม่น' : 'ไม่ระบุ',
                                    'เพขรบุรี':'เพชรบุรี', 'เพขรบูรณื': 'เพชรบูรณ์', 'เพขรบูรณ์':'เพชรบูรณ์',  'เพชรบุรณ์':'เพชรบูรณ์',
                                    'เพชรบุรี':'เพชรบุรี', 'เพชรบุรึ':'เพชรบุรี', 'เพชรบุุรี':'เพชรบุรี', 'เพชรบุูรณ์':'เพชรบูรณ์',
                                    'เพชรบูรณ์':'เพชรบูรณ์', 'เพชรบูรณ์\xa0':'เพชรบูรณ์',  'เพชรบูร์':'เพชรบูรณ์', 'เพชรบููรณ์':'เพชรบูรณ์',
                                    'เมือง':'ไม่ระบุ', 'เมืองตาก':'ตาก', 'เมืองน่าน':'น่าน', 'เมืองปัตตานี':'ไม่ระบุ',
                                    'เรือ':'ไม่ระบุ', 'เลย':'เลย',  'เลย\xa0':'เลย',  'เวียงจันทร์':'ไม่ระบุ'})
re_name3
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# ...

# %%
re_name4 = re_name3.replace({'เวียงสา':'ไม่ระบุ', 'แม่ทะ':'ไม่ระบุ', 'แพร่':'แพร่', 'แม่ฮ่องสอน':'แม่ฮ่องสอน',
                                    'แล้วป่วย':'ไม่ระบุ', 'โพธิ์ทอง':'ไม่ระบุ', 'ไชโย':'ไม่ระบุ', 'ไม่มีชื่อหอพัก':'ไม่ระบุ',
                                    'ไม่ระบุ':'ไม่ระบุ', 'หนวงบัวลำภู': 'หนองบัวลำภู', 'หนองคาย': 'หนองคาย', 'หนองงคาย': 'หนองคาย',
                                    'หนองบัวภู': 'หนองบัวลำภู', 'หนองบัวลำพูน': 'หนองบัวลำภู', 'หนองบัวลำภู': 'หนองบัวลำภู', 'หนองบัวลําภู': 'หนองบัวลำภู',
                                    'หนองบััวลำภู': 'หนองบัวลำภู', 'หนองม่วงไข่': 'ไม่ระบุ', 'หนอบัวลำภู': 'หนองบัวลำภู', 'หลายจังหวัด': 'ไม่ระบุ',
                                    'หัวหิน': 'ไม่ระบุ', 'ห้วยขวาง': 'ไม่ระบุ', 'อยุทธยา': 'พระนครศรีอยุธยา', 'อยุธยา': 'พระนครศรีอยุธยา',
                                    'อยุุธยา': 'พระนครศรีอยุธยา', 'อำนาจเจริญ':  'อำนาจเจริญ', 'อำนาจเจิญ':  'อำนาจเจริญ', 'อำนาญเจริญ':  'อำนาจเจริญ',
                                    'อำนาเจริญ':  'อำนาจเจริญ', 'อิสราเอล':  'ไม่ระบุ', 'อุดธานี': 'อุดรธานี', 'อุดร': 'อุดรธานี',
                                    'อุดรธาณี': 'อุดรธานี', 'อุดรธานี': 'อุดรธานี', 'อุดรธานี\xa0': 'อุดรธานี', 'อุดรธานีี': 'อุดรธานี',
                                    'อุดรราชธานี': 'อุดรธานี', 'อุตรดิตถ์': 'อุตรดิตถ์', 'อุตรดิตถ์\xa0': 'อุตรดิตถ์', 'อุตรดิตถ์์': 'อุตรดิตถ์',
                                    'อุตรดิษถ์': 'อุตรดิตถ์', 'อุตรดิิตถ์': 'อุตรดิตถ์', 'อุตรติดถ์': 'อุตรดิตถ์', 'อุทัยธานี': 'อุทัยธานี',
                                    'อุทัยานี': 'อุทัยธานี', 'อุบลราขธานี': 'อุบลราชธานี', 'อุบลราชธานี': 'อุบลราชธานี', 'อุบลราชธานี\xa0': 'อุบลราชธานี',
                                    'อุุครดิตถ์': 'อุตรดิตถ์', 'อุุดรธาน': 'อุดรธานี', 'อุุดรธานี': 'อุดรธานี', 'อุุตรดิตถ์': 'อุตรดิตถ์',
                                    'อุุทัยธานี': 'อุทัยธานี', 'อุุบลราชธานี': 'อุบลราชธานี', 'อ่งทอง': 'อ่างทอง', 'อ่างทอง': 'อ่างทอง',
                                    'อ่างทอง\xa0': 'อ่างทอง', 'อํานาจเจริญ': 'อำนาจเจริญ', 'เชิงเทรา': 'ฉะเชิงเทรา', 'เชียงราย': 'เชียงราย',
                                    'เชียงใหม่': 'เชียงใหม่', 'เชียรใหญ่': 'เชียงใหม่', 'เชีียงราย': 'เชียงราย', 'เชีียงใหม่': 'เชียงราย', 'เด่นชัย':'ไม่ระบุ',
                                    'พัังงา':'พังงา','พิจิตร':'พิจิตร','พิษณุโลก': 'พิษณุโลก','พิษณุโลก\xa0': 'พิษณุโลก',
                                    'พิษณูโลก': 'พิษณุโลก','ฟินแลนด์': 'ไม่ระบุ','ภาษีเจริญ': 'ไม่ระบุ','ภุเก็ต': 'ภูเก็ต',
                                    'ภูุเก็ต': 'ภูเก็ต','ภููเก็ต': 'ภูเก็ต','ภูเก็ต': 'ภูเก็ต','ภูเก็็ต': 'ภูเก็ต','ภูเพียง': 'ภูเก็ต'})
re_name4
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# ...

# %%
data1_finish = re_name4

# %%
set(data1_finish['province_of_onset'])
# Out:
# {nan,
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
# ...

# %% [markdown]
# # ดึงข้อมูลไฟล์ 2

# %%
province_file_path= os.path.join(path,'data2.csv')
print(province_file_path)
# Out:
# /content/drive/My Drive/DataViz22_data/data2.csv

# %%
region = pd.read_csv(province_file_path)
region
# Out:
#    province_of_onset 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0      กรุงเทพมหานคร                   กลาง                 กลาง
# 1             กระบี่                    ใต้                  ใต้
# 2          กาญจนบุรี                ตะวันตก                 กลาง
# 3          กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4          กำแพงเพชร                   กลาง                เหนือ
# ..               ...                    ...                  ...
# 72       หนองบัวลำภู     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 73           สุโขทัย                   กลาง                เหนือ
# 74        สุพรรณบุรี                   กลาง                 กลาง
# 75      สุราษฎร์ธานี                    ใต้                  ใต้
# 76          สุรินทร์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
#
#          5 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0                             กลาง                      กลาง
# 1   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# ...

# %% [markdown]
# # ดึงข้อมูลไฟล์ 3

# %%
bed_hos_file_path= os.path.join(path,'data3.csv')
print(bed_hos_file_path)
# Out:
# /content/drive/My Drive/DataViz22_data/data3.csv

# %%
field_hos= pd.read_csv(bed_hos_file_path)
field_hos
# Out:
#    province_of_onset จำนวนเตียงของรพ.สนาม อว.
# 0      กรุงเทพมหานคร                      340
# 1             กระบี่                        0
# 2          กาญจนบุรี                        0
# 3          กาฬสินธุ์                        0
# 4          กำแพงเพชร                      147
# ..               ...                      ...
# 72        อำนาจเจริญ                      300
# 73          อุดรธานี                      436
# 74         อุตรดิตถ์                      225
# 75         อุทัยธานี                        0
# 76       อุบลราชธานี                      511
#
# [77 rows x 2 columns]

# %% [markdown]
# # ต่อตารางไฟล์รวม1 กับ ไฟล์ 2 แกน X

# %%
#เชื่อมตาราง โดยใช้คำสั่ง merge
data_1 = data1_finish.merge(region) 
data_1
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 0              1     12/1/2020  หญิง  61.0   ปี       China
# 1              2     17/1/2020  หญิง  74.0   ปี       China
# 2              4     22/1/2020   ชาย  68.0   ปี       China
# 3              5     24/1/2020  หญิง  66.0   ปี       China
# 4              6     25/1/2020  หญิง  33.0   ปี       China
# ...          ...           ...   ...   ...  ...         ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี    Thailand
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี    Thailand
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี    Thailand
#
#                                      risk province_of_onset  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %% [markdown]
# # เชื่อมตาราง (12) กับ ไฟล์ 3

# %%
data_final_pre = data_1.merge(field_hos) 
data_final_pre
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 0              1     12/1/2020  หญิง  61.0   ปี       China
# 1              2     17/1/2020  หญิง  74.0   ปี       China
# 2              4     22/1/2020   ชาย  68.0   ปี       China
# 3              5     24/1/2020  หญิง  66.0   ปี       China
# 4              6     25/1/2020  หญิง  33.0   ปี       China
# ...          ...           ...   ...   ...  ...         ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี    Thailand
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี    Thailand
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี    Thailand
#
#                                      risk province_of_onset  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
set(data_final_pre['province_of_onset'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
# ...

# %%
set(data_final_pre['sex'])
# Out:
# {nan, 'ช', 'ชาย', 'ญ', 'นาย', 'ร.ต.ท.', 'หญิง', 'หณิง', 'หห'}

# %%
re_sex = data_final_pre.replace({'ช':'ชาย', 'ชาย':'ชาย', 'ญ':'หญิง', 'นาย':'ชาย', 'ร.ต.ท.':'ไม่ระบุ', 'หญิง':'หญิง', 'หณิง':'หญิง', 'หห':'ไม่ระบุ'})
re_sex
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 0              1     12/1/2020  หญิง  61.0   ปี       China
# 1              2     17/1/2020  หญิง  74.0   ปี       China
# 2              4     22/1/2020   ชาย  68.0   ปี       China
# 3              5     24/1/2020  หญิง  66.0   ปี       China
# 4              6     25/1/2020  หญิง  33.0   ปี       China
# ...          ...           ...   ...   ...  ...         ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี    Thailand
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี    Thailand
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี    Thailand
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี    Thailand
#
#                                      risk province_of_onset  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
set(re_sex['sex'])
# Out:
# {nan, 'ชาย', 'หญิง', 'ไม่ระบุ'}

# %%
data_final = re_sex

# %%
data_final.isnull().any().any()
# Out:
# True

# %%
data_final.isnull().any()
# Out:
# No.                          False
# announce_date                False
# sex                           True
# age                           True
# Unit                          True
# nationality                   True
# risk                          True
# province_of_onset            False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 5 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# จำนวนเตียงของรพ.สนาม อว.     False
# dtype: bool

# %%
data_final[['sex']]=data_final[['sex']].fillna('ไม่ได้ระบุ')
data_final[['age']]=data_final[['age']].fillna('ไม่ได้ระบุ')
data_final[['Unit']]=data_final[['Unit']].fillna('ไม่ได้ระบุ')
data_final[['nationality']]=data_final[['nationality']].fillna('ไม่ได้ระบุ')
data_final[['risk']]=data_final[['risk']].fillna('ไม่ได้ระบุ')

# แทนค่า missing ด้วยคำว่า ไม่ได้ระบุ

# %%
data_final.isnull().any() # check missing again
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# nationality                  False
# risk                         False
# province_of_onset            False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 5 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# จำนวนเตียงของรพ.สนาม อว.     False
# dtype: bool

# %% [markdown]
# # แบ่งไฟล์ข้อมูล

# %%
data_project1=data_final[data_final.announce_date.str.contains('2020')]
data_project1
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 0           1     12/1/2020  หญิง  61.0   ปี       China
# 1           2     17/1/2020  หญิง  74.0   ปี       China
# 2           4     22/1/2020   ชาย  68.0   ปี       China
# 3           5     24/1/2020  หญิง  66.0   ปี       China
# 4           6     25/1/2020  หญิง  33.0   ปี       China
# ...       ...           ...   ...   ...  ...         ...
# 2864535  5922    26/12/2020  หญิง  47.0   ปี    Thailand
# 2869271  5809    24/12/2020  หญิง  44.0   ปี    Thailand
# 2869272  6689    30/12/2020   ชาย  35.0   ปี    Thailand
# 2886001  6288    29/12/2020   ชาย  55.0   ปี    Thailand
# 2898485  6467    30/12/2020   ชาย  57.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
b1=list() 
for each_row in data_project1.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=1 )  and (int(each_row[1]['announce_date'].split('/')[1])< 4) : 
        b1.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        b1.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project1[b1] # แสดงผลลัพธ์
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 0           1     12/1/2020  หญิง  61.0   ปี       China
# 1           2     17/1/2020  หญิง  74.0   ปี       China
# 2           4     22/1/2020   ชาย  68.0   ปี       China
# 3           5     24/1/2020  หญิง  66.0   ปี       China
# 4           6     25/1/2020  หญิง  33.0   ปี       China
# ...       ...           ...   ...   ...  ...         ...
# 2684680  1410     30/3/2020   ชาย  39.0   ปี    Thailand
# 2689781  1463     30/3/2020   ชาย  51.0   ปี    Thailand
# 2689782  1543     31/3/2020   ชาย   9.0   ปี    Thailand
# 2689783  1544     31/3/2020  หญิง  44.0   ปี    Thailand
# 2699008  1530     31/3/2020  หญิง  21.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
data_pj_2020_1 = data_project1[b1]
data_pj_2020_1
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 0           1     12/1/2020  หญิง  61.0   ปี       China
# 1           2     17/1/2020  หญิง  74.0   ปี       China
# 2           4     22/1/2020   ชาย  68.0   ปี       China
# 3           5     24/1/2020  หญิง  66.0   ปี       China
# 4           6     25/1/2020  หญิง  33.0   ปี       China
# ...       ...           ...   ...   ...  ...         ...
# 2684680  1410     30/3/2020   ชาย  39.0   ปี    Thailand
# 2689781  1463     30/3/2020   ชาย  51.0   ปี    Thailand
# 2689782  1543     31/3/2020   ชาย   9.0   ปี    Thailand
# 2689783  1544     31/3/2020  หญิง  44.0   ปี    Thailand
# 2699008  1530     31/3/2020  หญิง  21.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
b2=list() 
for each_row in data_project1.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=4 )  and (int(each_row[1]['announce_date'].split('/')[1])< 7) : 
        b2.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        b2.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project1[b2] # แสดงผลลัพธ์
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 957      1653      1/4/2020   ชาย  76.0   ปี    Thailand
# 958      1658      1/4/2020  หญิง  32.0   ปี    Thailand
# 959      1659      1/4/2020  หญิง  29.0   ปี    Thailand
# 960      1660      1/4/2020  หญิง  29.0   ปี    Thailand
# 961      1661      1/4/2020  หญิง  27.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 2812475  2578     13/4/2020   ชาย  41.0   ปี    Thailand
# 2812476  2579     13/4/2020   ชาย  34.0   ปี    Thailand
# 2812477  2614     14/4/2020   ชาย  40.0   ปี    Thailand
# 2826659  2433     10/4/2020   ชาย   7.0   ปี    Thailand
# 2826660  2585     14/4/2020  หญิง  42.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 957                                          สนามมวย     กรุงเทพมหานคร
# 958                                      สถานบันเทิง     กรุงเทพมหานคร
# ...

# %%
data_pj_2020_2 = data_project1[b2]
data_pj_2020_2
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 957      1653      1/4/2020   ชาย  76.0   ปี    Thailand
# 958      1658      1/4/2020  หญิง  32.0   ปี    Thailand
# 959      1659      1/4/2020  หญิง  29.0   ปี    Thailand
# 960      1660      1/4/2020  หญิง  29.0   ปี    Thailand
# 961      1661      1/4/2020  หญิง  27.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 2812475  2578     13/4/2020   ชาย  41.0   ปี    Thailand
# 2812476  2579     13/4/2020   ชาย  34.0   ปี    Thailand
# 2812477  2614     14/4/2020   ชาย  40.0   ปี    Thailand
# 2826659  2433     10/4/2020   ชาย   7.0   ปี    Thailand
# 2826660  2585     14/4/2020  หญิง  42.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 957                                          สนามมวย     กรุงเทพมหานคร
# 958                                      สถานบันเทิง     กรุงเทพมหานคร
# ...

# %%
b3=list() 
for each_row in data_project1.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=7 )  and (int(each_row[1]['announce_date'].split('/')[1])< 10) : 
        b3.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        b3.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project1[b3] # แสดงผลลัพธ์
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 1559     3182      4/7/2020   ชาย  38.0   ปี    Thailand
# 1560     3187      5/7/2020  หญิง  17.0   ปี    Thailand
# 1561     3188      5/7/2020  หญิง  35.0   ปี    Thailand
# 1562     3189      5/7/2020   ชาย  38.0   ปี    Thailand
# 1563     3190      5/7/2020   ชาย  42.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 1082275  3561     30/9/2020   ชาย  34.0   ปี    Thailand
# 1082276  3562     30/9/2020   ชาย  31.0   ปี       India
# 1344973  3439      5/9/2020   ชาย  24.0   ปี  Bangladesh
# 1898835  3220     13/7/2020   ชาย  43.0   ปี       Egypt
# 2280412  3313      1/8/2020   ชาย  29.0   ปี      Serbia
#
#                                                  risk province_of_onset  \
# 1559                                 State Quarantine     กรุงเทพมหานคร
# 1560                                 State Quarantine     กรุงเทพมหานคร
# ...

# %%
data_pj_2020_3 = data_project1[b3]
data_pj_2020_3
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 1559     3182      4/7/2020   ชาย  38.0   ปี    Thailand
# 1560     3187      5/7/2020  หญิง  17.0   ปี    Thailand
# 1561     3188      5/7/2020  หญิง  35.0   ปี    Thailand
# 1562     3189      5/7/2020   ชาย  38.0   ปี    Thailand
# 1563     3190      5/7/2020   ชาย  42.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 1082275  3561     30/9/2020   ชาย  34.0   ปี    Thailand
# 1082276  3562     30/9/2020   ชาย  31.0   ปี       India
# 1344973  3439      5/9/2020   ชาย  24.0   ปี  Bangladesh
# 1898835  3220     13/7/2020   ชาย  43.0   ปี       Egypt
# 2280412  3313      1/8/2020   ชาย  29.0   ปี      Serbia
#
#                                                  risk province_of_onset  \
# 1559                                 State Quarantine     กรุงเทพมหานคร
# 1560                                 State Quarantine     กรุงเทพมหานคร
# ...

# %%
b4=list() 
for each_row in data_project1.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=10 )  and (int(each_row[1]['announce_date'].split('/')[1])< 13) : 
        b4.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        b4.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project1[b4] # แสดงผลลัพธ์
# Out:
#           No. announce_date   sex   age Unit  nationality  \
# 1706     3566     1/10/2020   ชาย  26.0   ปี  Philippines
# 1707     3568     1/10/2020   ชาย  41.0   ปี        India
# 1708     3572     2/10/2020   ชาย   1.0   ปี        India
# 1709     3577     3/10/2020   ชาย  35.0   ปี        India
# 1710     3578     3/10/2020   ชาย  43.0   ปี        India
# ...       ...           ...   ...   ...  ...          ...
# 2864535  5922    26/12/2020  หญิง  47.0   ปี     Thailand
# 2869271  5809    24/12/2020  หญิง  44.0   ปี     Thailand
# 2869272  6689    30/12/2020   ชาย  35.0   ปี     Thailand
# 2886001  6288    29/12/2020   ชาย  55.0   ปี     Thailand
# 2898485  6467    30/12/2020   ชาย  57.0   ปี     Thailand
#
#                                                  risk province_of_onset  \
# 1706     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# 1707     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# ...

# %%
data_pj_2020_4 = data_project1[b4]
data_pj_2020_4
# Out:
#           No. announce_date   sex   age Unit  nationality  \
# 1706     3566     1/10/2020   ชาย  26.0   ปี  Philippines
# 1707     3568     1/10/2020   ชาย  41.0   ปี        India
# 1708     3572     2/10/2020   ชาย   1.0   ปี        India
# 1709     3577     3/10/2020   ชาย  35.0   ปี        India
# 1710     3578     3/10/2020   ชาย  43.0   ปี        India
# ...       ...           ...   ...   ...  ...          ...
# 2864535  5922    26/12/2020  หญิง  47.0   ปี     Thailand
# 2869271  5809    24/12/2020  หญิง  44.0   ปี     Thailand
# 2869272  6689    30/12/2020   ชาย  35.0   ปี     Thailand
# 2886001  6288    29/12/2020   ชาย  55.0   ปี     Thailand
# 2898485  6467    30/12/2020   ชาย  57.0   ปี     Thailand
#
#                                                  risk province_of_onset  \
# 1706     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# 1707     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# ...

# %%
data_project2=data_final[data_final.announce_date.str.contains('2021')]
data_project2
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 2214        6890      1/1/2021  หญิง  36.0   ปี    Cambodia
# 2215        6891      1/1/2021   ชาย  44.0   ปี    Thailand
# 2216        6895      1/1/2021   ชาย  59.0   ปี    Thailand
# 2217        6896      1/1/2021   ชาย  75.0   ปี    Thailand
# 2218        6897      1/1/2021   ชาย  30.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 2922358  2216060    29/12/2021   ชาย  22.0   ปี    Thailand
# 2922359  2216061    29/12/2021   ชาย  47.0   ปี    Thailand
# 2922360  2216062    29/12/2021  หญิง  48.0   ปี    Thailand
# 2922361  2216063    29/12/2021  หญิง  34.0   ปี    Thailand
# 2922362  2216064    29/12/2021   ชาย  35.0   ปี    Thailand
#
#                                                       risk province_of_onset  \
# 2214     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 2215                                           สถานบันเทิง     กรุงเทพมหานคร
# ...

# %%
a1=list() 
for each_row in data_project2.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>0 )  and (int(each_row[1]['announce_date'].split('/')[1])< 4) : 
        a1.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        a1.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project2[a1] # แสดงผลลัพธ์
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 2214     6890      1/1/2021  หญิง  36.0   ปี    Cambodia
# 2215     6891      1/1/2021   ชาย  44.0   ปี    Thailand
# 2216     6895      1/1/2021   ชาย  59.0   ปี    Thailand
# 2217     6896      1/1/2021   ชาย  75.0   ปี    Thailand
# 2218     6897      1/1/2021   ชาย  30.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 2886021  9277      6/1/2021   ชาย  48.0   ปี    Thailand
# 2886022  9278      6/1/2021  หญิง  16.0   ปี    Thailand
# 2886023  9504      7/1/2021   ชาย  23.0   ปี    Thailand
# 2886024  9894      9/1/2021  หญิง  48.0   ปี    Thailand
# 2913268  8479      5/1/2021  หญิง  23.0   ปี        Laos
#
#                                                       risk province_of_onset  \
# 2214     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 2215                                           สถานบันเทิง     กรุงเทพมหานคร
# ...

# %%
data_pj_2021_1 = data_project2[a1]
data_pj_2021_1
# Out:
#           No. announce_date   sex   age Unit nationality  \
# 2214     6890      1/1/2021  หญิง  36.0   ปี    Cambodia
# 2215     6891      1/1/2021   ชาย  44.0   ปี    Thailand
# 2216     6895      1/1/2021   ชาย  59.0   ปี    Thailand
# 2217     6896      1/1/2021   ชาย  75.0   ปี    Thailand
# 2218     6897      1/1/2021   ชาย  30.0   ปี    Thailand
# ...       ...           ...   ...   ...  ...         ...
# 2886021  9277      6/1/2021   ชาย  48.0   ปี    Thailand
# 2886022  9278      6/1/2021  หญิง  16.0   ปี    Thailand
# 2886023  9504      7/1/2021   ชาย  23.0   ปี    Thailand
# 2886024  9894      9/1/2021  หญิง  48.0   ปี    Thailand
# 2913268  8479      5/1/2021  หญิง  23.0   ปี        Laos
#
#                                                       risk province_of_onset  \
# 2214     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 2215                                           สถานบันเทิง     กรุงเทพมหานคร
# ...

# %%
a2=list() 
for each_row in data_project2.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=4 )  and (int(each_row[1]['announce_date'].split('/')[1])< 7) : 
        a2.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        a2.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project2[a2] # แสดงผลลัพธ์
# Out:
#             No. announce_date   sex         age        Unit nationality  \
# 4318      28875      1/4/2021  หญิง        34.0          ปี    Thailand
# 4319      28876      1/4/2021   ชาย        29.0          ปี       Burma
# 4320      28877      1/4/2021   ชาย        33.0          ปี    Thailand
# 4321      28878      1/4/2021   ชาย        24.0          ปี    Thailand
# 4322      28879      1/4/2021  หญิง        62.0          ปี    Thailand
# ...         ...           ...   ...         ...         ...         ...
# 2920537  238368     26/6/2021  หญิง        27.0          ปี    Thailand
# 2920538  252104     29/6/2021   ชาย        41.0          ปี    Thailand
# 2920539  252105     29/6/2021   ชาย  ไม่ได้ระบุ  ไม่ได้ระบุ    Thailand
# 2920540  252127     29/6/2021   ชาย        62.0          ปี    Thailand
# 2920541  252128     29/6/2021  หญิง        46.0          ปี    Thailand
#
#                                                      risk province_of_onset  \
# ...

# %%
data_pj_2021_2 = data_project2[a2]
data_pj_2021_2
# Out:
#             No. announce_date   sex         age        Unit nationality  \
# 4318      28875      1/4/2021  หญิง        34.0          ปี    Thailand
# 4319      28876      1/4/2021   ชาย        29.0          ปี       Burma
# 4320      28877      1/4/2021   ชาย        33.0          ปี    Thailand
# 4321      28878      1/4/2021   ชาย        24.0          ปี    Thailand
# 4322      28879      1/4/2021  หญิง        62.0          ปี    Thailand
# ...         ...           ...   ...         ...         ...         ...
# 2920537  238368     26/6/2021  หญิง        27.0          ปี    Thailand
# 2920538  252104     29/6/2021   ชาย        41.0          ปี    Thailand
# 2920539  252105     29/6/2021   ชาย  ไม่ได้ระบุ  ไม่ได้ระบุ    Thailand
# 2920540  252127     29/6/2021   ชาย        62.0          ปี    Thailand
# 2920541  252128     29/6/2021  หญิง        46.0          ปี    Thailand
#
#                                                      risk province_of_onset  \
# ...

# %%
a3=list() 
for each_row in data_project2.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=7 )  and (int(each_row[1]['announce_date'].split('/')[1])< 10) : 
        a3.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        a3.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project2[a3] # แสดงผลลัพธ์
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 70700     259637      1/7/2021  หญิง  91.0   ปี    Thailand
# 70701     259638      1/7/2021  หญิง  39.0   ปี    Thailand
# 70702     259639      1/7/2021  หญิง  40.0   ปี    Thailand
# 70703     259640      1/7/2021   ชาย  42.0   ปี    Thailand
# 70704     259641      1/7/2021  หญิง  29.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 2921373  1586618     29/9/2021   ชาย  53.0   ปี    Thailand
# 2921374  1586619     29/9/2021  หญิง   5.0   ปี    Thailand
# 2921375  1586620     29/9/2021   ชาย   9.0   ปี    Thailand
# 2921376  1597686     30/9/2021  หญิง  23.0   ปี    Thailand
# 2921377  1597687     30/9/2021  หญิง  38.0   ปี    Thailand
#
#                                                      risk province_of_onset  \
# 70700         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 70701         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# ...

# %%
data_pj_2021_3 = data_project2[a3]
data_pj_2021_3
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 70700     259637      1/7/2021  หญิง  91.0   ปี    Thailand
# 70701     259638      1/7/2021  หญิง  39.0   ปี    Thailand
# 70702     259639      1/7/2021  หญิง  40.0   ปี    Thailand
# 70703     259640      1/7/2021   ชาย  42.0   ปี    Thailand
# 70704     259641      1/7/2021  หญิง  29.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 2921373  1586618     29/9/2021   ชาย  53.0   ปี    Thailand
# 2921374  1586619     29/9/2021  หญิง   5.0   ปี    Thailand
# 2921375  1586620     29/9/2021   ชาย   9.0   ปี    Thailand
# 2921376  1597686     30/9/2021  หญิง  23.0   ปี    Thailand
# 2921377  1597687     30/9/2021  หญิง  38.0   ปี    Thailand
#
#                                                      risk province_of_onset  \
# 70700         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 70701         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# ...

# %%
a4=list() 
for each_row in data_project2.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=10 )  and (int(each_row[1]['announce_date'].split('/')[1])< 13) : 
        a4.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        a4.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project2[a4] # แสดงผลลัพธ์
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 359249   1603764     1/10/2021   ชาย  23.0   ปี    Thailand
# 359250   1604215     1/10/2021  หญิง  57.0   ปี    Thailand
# 359251   1604216     1/10/2021  หญิง  76.0   ปี    Thailand
# 359252   1604217     1/10/2021   ชาย  66.0   ปี    Thailand
# 359253   1604218     1/10/2021  หญิง   6.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 2922358  2216060    29/12/2021   ชาย  22.0   ปี    Thailand
# 2922359  2216061    29/12/2021   ชาย  47.0   ปี    Thailand
# 2922360  2216062    29/12/2021  หญิง  48.0   ปี    Thailand
# 2922361  2216063    29/12/2021  หญิง  34.0   ปี    Thailand
# 2922362  2216064    29/12/2021   ชาย  35.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 359249                                         อื่นๆ     กรุงเทพมหานคร
# 359250   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# ...

# %%
data_pj_2021_4 = data_project2[a4]
data_pj_2021_4
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 359249   1603764     1/10/2021   ชาย  23.0   ปี    Thailand
# 359250   1604215     1/10/2021  หญิง  57.0   ปี    Thailand
# 359251   1604216     1/10/2021  หญิง  76.0   ปี    Thailand
# 359252   1604217     1/10/2021   ชาย  66.0   ปี    Thailand
# 359253   1604218     1/10/2021  หญิง   6.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 2922358  2216060    29/12/2021   ชาย  22.0   ปี    Thailand
# 2922359  2216061    29/12/2021   ชาย  47.0   ปี    Thailand
# 2922360  2216062    29/12/2021  หญิง  48.0   ปี    Thailand
# 2922361  2216063    29/12/2021  หญิง  34.0   ปี    Thailand
# 2922362  2216064    29/12/2021   ชาย  35.0   ปี    Thailand
#
#                                                 risk province_of_onset  \
# 359249                                         อื่นๆ     กรุงเทพมหานคร
# 359250   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# ...

# %%
data_project3=data_final[data_final.announce_date.str.contains('2022')]
data_project3
# Out:
#              No. announce_date   sex   age Unit    nationality   risk  \
# 424539   2223462      1/1/2022  หญิง  43.0   ปี       Thailand  อื่นๆ
# 424540   2223463      1/1/2022  หญิง  23.0   ปี       Thailand  อื่นๆ
# 424541   2223817      1/1/2022  หญิง  38.0   ปี       Thailand  อื่นๆ
# 424542   2223818      1/1/2022   ชาย  46.0   ปี       Thailand  อื่นๆ
# 424543   2223819      1/1/2022  หญิง  25.0   ปี  Laotian / Lao  อื่นๆ
# ...          ...           ...   ...   ...  ...            ...    ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี       Thailand  อื่นๆ
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี       Thailand  อื่นๆ
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี       Thailand  อื่นๆ
#
#         province_of_onset 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# ...

# %%
a5=list() 
for each_row in data_project3.iterrows(): # loop each_row (แต่ละแถว) ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1])>=1 )  and (int(each_row[1]['announce_date'].split('/')[1])< 4) : 
        a5.append(True) # หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น True เก็บไว้>>เพื่อไว้ใช้ต่อ
    else:
        a5.append(False) #หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน list j ที่สร้างไว้ | มันจะเป็นappend เป็น False เก็บไว้ >>เพื่อไม่ใช้ต่อ

data_project3[a5] # แสดงผลลัพธ์
# Out:
#              No. announce_date   sex   age Unit    nationality   risk  \
# 424539   2223462      1/1/2022  หญิง  43.0   ปี       Thailand  อื่นๆ
# 424540   2223463      1/1/2022  หญิง  23.0   ปี       Thailand  อื่นๆ
# 424541   2223817      1/1/2022  หญิง  38.0   ปี       Thailand  อื่นๆ
# 424542   2223818      1/1/2022   ชาย  46.0   ปี       Thailand  อื่นๆ
# 424543   2223819      1/1/2022  หญิง  25.0   ปี  Laotian / Lao  อื่นๆ
# ...          ...           ...   ...   ...  ...            ...    ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี       Thailand  อื่นๆ
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี       Thailand  อื่นๆ
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี       Thailand  อื่นๆ
#
#         province_of_onset 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# ...

# %%
data_pj_2022 = data_project3[a5]
data_pj_2022
# Out:
#              No. announce_date   sex   age Unit    nationality   risk  \
# 424539   2223462      1/1/2022  หญิง  43.0   ปี       Thailand  อื่นๆ
# 424540   2223463      1/1/2022  หญิง  23.0   ปี       Thailand  อื่นๆ
# 424541   2223817      1/1/2022  หญิง  38.0   ปี       Thailand  อื่นๆ
# 424542   2223818      1/1/2022   ชาย  46.0   ปี       Thailand  อื่นๆ
# 424543   2223819      1/1/2022  หญิง  25.0   ปี  Laotian / Lao  อื่นๆ
# ...          ...           ...   ...   ...  ...            ...    ...
# 2925479  3292162     18/3/2022   ชาย  53.0   ปี       Thailand  อื่นๆ
# 2925480  3292163     18/3/2022  หญิง  34.0   ปี       Thailand  อื่นๆ
# 2925481  3292164     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925482  3292165     18/3/2022  หญิง  54.0   ปี       Thailand  อื่นๆ
# 2925483  3292166     18/3/2022  หญิง  16.0   ปี       Thailand  อื่นๆ
#
#         province_of_onset 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# ...

# %% [markdown]
# # Save Table  9 ไฟล์ มีดังนี้
# 1. ไฟล์ข้อมูลไตรมาสที่ 1 ปี 2020 (1/1/2020 - 31/3/2020)
# 2. ไฟล์ข้อมูลไตรมาสที่ 2 ปี 2020 (1/4/2020 - 30/6/2020)
# 3. ไฟล์ข้อมูลไตรมาสที่ 3 ปี 2020 (1/7/2020 - 30/9/2020)
# 4. ไฟล์ข้อมูลไตรมาสที่ 4 ปี 2020 (1/10/2020 - 31/12/2020)
# 5. ไฟล์ข้อมูลไตรมาสที่ 1 ปี 2021 (1/1/2021 - 31/3/2021)
# 6. ไฟล์ข้อมูลไตรมาสที่ 2 ปี 2021 (1/4/2021 - 30/6/2021)
# 7. ไฟล์ข้อมูลไตรมาสที่ 3 ปี 2021 (1/7/2021 - 30/9/2021)
# 8. ไฟล์ข้อมูลไตรมาสที่ 4 ปี 2021 (1/10/2021 - 31/12/2021)
# 9. ไฟล์ข้อมูลไตรมาสที่ 1 ปี 2022 (1/1/2022 - 18/3/2022)

# %%
data_pj_2020_1.to_csv(os.path.join(path,'studio1_1.csv'))
data_pj_2020_1.to_csv('studio1_1.csv')

# %%
data_pj_2020_2.to_csv(os.path.join(path,'studio1_2.csv'))
data_pj_2020_2.to_csv('studio1_2.csv')

# %%
data_pj_2020_3.to_csv(os.path.join(path,'studio1_3.csv'))
data_pj_2020_3.to_csv('studio1_3.csv')

# %%
data_pj_2020_4.to_csv(os.path.join(path,'studio1_4.csv'))
data_pj_2020_4.to_csv('studio1_4.csv')

# %%
data_pj_2021_1.to_csv(os.path.join(path,'studio2_1.csv'))
data_pj_2021_1.to_csv('studio2_1.csv')

# %%
data_pj_2021_2.to_csv(os.path.join(path,'studio2_2.csv'))
data_pj_2021_2.to_csv('studio2_2.csv')

# %%
data_pj_2021_3.to_csv(os.path.join(path,'studio2_3.csv'))
data_pj_2021_3.to_csv('studio2_3.csv')

# %%
data_pj_2021_4.to_csv(os.path.join(path,'studio2_4.csv'))
data_pj_2021_4.to_csv('studio2_4.csv')

# %%
data_pj_2022.to_csv(os.path.join(path,'studio3.csv'))
data_pj_2022.to_csv('studio3.csv')
